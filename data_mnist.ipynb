# %%
import pickle
import os
import numpy as np
from pathlib import Path
import yaml

os.chdir("/home/cachao/Projects/CNN/data")

# %%
with open("Fashion_MNIST/fashion_train_images", "rb") as f:
        train_images = pickle.load(f)

with open("Fashion_MNIST/fashion_train_values", "rb") as f:
    train_values = pickle.load(f)

with open("Fashion_MNIST/fashion_test_images", "rb") as f:
    test_images = pickle.load(f)

with open("Fashion_MNIST/fashion_test_values", "rb") as f:
    test_values = pickle.load(f)

# %%
np.savez_compressed("fashion_mnist.npz", train_images=train_images, train_values=train_values, test_images=test_images, test_values=test_values)
